# %% [markdown]
# # TP 4 - Boucles imbriquées
#
# Pensez à :
# - tester vos fonctions (pas seulement les tests proposés)
# - vos spécifications et autres commentaires utiles
# - vos compléxité

# %% [markdown]
# ## Exercice 1 : Calcul de sommes doubles
#
# **Question 1 : Ecrire une fonction `somme_double_1(n)` qui, étant donné un entier `n`, renvoie la valeur de la somme** $$
# \sum_{i=1}^n \sum_{j=1}^n i^j
# $$

# %%
# Code à compléter

# %%
somme_double_1(5)
# 5699

# %% [markdown]
# **Question 2 : Ecrire une fonction somme_double_2(n) qui, étant donné un entier n, renvoie les valeurs des deux sommes :**
# $$ S_1 = \sum_{i=1}^n \sum_{j=1}^n i/j$$
# $$S_2 = \sum_{j=1}^n \sum_{i=1}^j i/j$$
#
# En python on peut renvoyer un **tuple** en faisant :
# `return (x, y)`

# %%
# Exemple de tuple
def je_retourne_2(x,y):
    return (x,y)

je_retourne_2(4,6)

# %%
# Code à compléter

# %%
somme_double_2(5)
#(10.0, 10.000000000000002)

# %% [markdown]
# ## Exercice 2 : Addition et multiplication de matrice
#
# En python on peut faire des matrices, ce sont des tableaux de tableau.
# On peut initialiser la matrice :
# $$ m =
# \begin{pmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6
# \end{pmatrix}
# $$
# en faisant :

# %%
m = [[1,2,3], [4,5,6]]

# %% [markdown]
# On peut accéder à la valeur à la ligne `i` et la colonne `j` en faisant `m[i][j]`. Attention les indices commencent à `0`.

# %%
m[0][1]
# Out:
# 2

# %% [markdown]
# **Question 1 : Ecrire une fonction `addition(m1, m2)` qui additionne deux matrice de taille n*m. Renvoyer `None` si les matrices ne peuvent pas être additionner.**

# %%
# Code à compléter

# %%
m1 = [[1,2], [4,5]]
m2 = [[3,5], [2,1]]
addition(m1, m2)
# [[4,7], [6,6]]

# %% [markdown]
# **Question 2 : Ecrire une fonction `multiplication(m1, m2)` qui multiplie deux matrice, `m1` de taille `n*m` et `m2` de taille `m*n`. Renvoyer `None` si les matrices ne peuvent pas être multiplier.**

# %%
# Code à compléter

# %%
m1 = [[1, 2, 3], [4, 5, 6]]
m2 = [[7, 8], [9, 10], [11, 12]]
multiplication(m1, m2)
# [[58, 64], [139, 154]]

# %%
m1 = [[1, 2, 3], [4, 5, 6]]
m2 = [[7, 8], [9, 10]]
multiplication(m1, m2)
# None

# %% [markdown]
# ## Exercice 3 : Recherche d'un mot dans un texte
#
# La liste `[1,3,5]` est une sous-liste de `[15,-12,1,3,5,19]`, ici par sous-liste on entend en un seul morceau. Ainsi, `[1,3,5]` n'est pas une sous-liste de `[1,2,3,4,5]`.\
# De même `"tar"` est contenu de `"il est tard"`.
#
# On cherche à déterminer si un motif apparaît dans une liste ou dans un texte. Les manipulations de listes et de chaînes de caractères étant proches, on demande d’écrire des codes qui vont fonctionner indifféremment sur les deux types de structure.
#
# Voici la démarche naïve de recherche d’un motif dans un texte qui sera programmée :
# - On effectue la recherche avec une boucle qui va considérer toutes les positions possibles pour le mot (on appelle position du mot l’indice python de la 1ère lettre du mot).
# - Pour chaque position i, on teste si le mot apparait en position i :
#     - Dans la 1ère fonction on autorise les slices (voir explication ci-dessous) pour cette comparaison
#     - Dans la 2ème fonction on autorise uniquement des comparaisons lettre à lettre
#
# Le terme anglais slice est associé à l’idée de découpage. En langage Python, cela permet d’extraire une tranche d’un objet itérable. Si `L` est une liste ou une chaine de caractères, `L[i:j]` renvoie une
# nouvelle liste ou chaine de caractère composée des éléments d’indices python `i` à `j-1` inclus de `L`.

# %%
s = 'il est tard'
s[3:8]

# %% [markdown]
# **Question 1 : En notant `t` la longueur du texte et `m` la longueur du mot, quelles sont les valeurs de `i` à considérer pour tester toutes les positions possibles du mot dans le texte? Comment récupérer à l’aide d’un slice le sous-mot du texte qui se trouve à la position `i` et qu’il faudra comparer avec mot?**

# %% [raw]
# Réponse ici :

# %% [markdown]
# **Question 2 : Ecrire une fonction `egaux(mot_1, mot_2)` qui renvoie `True` ssi `mot_1` est égal à `mot_2`.**

# %%
# Code à compléter

# %% [markdown]
# **Question 3 : Ecrire une fonction `recherche_motif_1(motif, texte)` qui, en utilisant les slices, étant donnés deux chaînes de caractères (ou deux listes) motif et texte, renvoie `True` si le mot est présent et `False` sinon.**

# %%
# Code à compléter

# %%
recherche_motif_1('tar', 'il est tard')
# True

# %%
recherche_motif_1([1,3,5], [15,-12,1,3,5,19])
# True

# %%
recherche_motif_1([1,3,5], [1,2,3,4,5])
# True

# %% [markdown]
# **Question 4 : Ecrire une fonction `recherche_motif_2(motif, texte)` qui a le même comportement mais n'utilise pas les slices.**

# %%
# Code à compléter

# %% [markdown]
# **Question 5 : Ecrire une fonction `positions_motif(motif, texte)` qui renvoie la liste, éventuellement vide, des positions du motif dans le texte.**

# %%
# Code à compléter

# %% [markdown]
# On va maintenant améliorer la complexité de cette algorithme de recherche de motif. \
# Pour cela on va utiliser l'algorithme de **Boyer-Moore** vu en cours. \
# Pour plus de facilité, on va maintenant se réstreindre à rechercher un motif dans un texte.
#
# **Question 6 : Écrire une fonction qui prends un motif et renvoie sa table de décalages sous forme de dictionnaire.**

# %%
# Code à compléter

# %% [markdown]
# **Question 7 : Écrire une fonction qui prends un `position_motif_boyer_moore(motif, texte)` qui renvoie la liste, éventuellement vide, des positions du motif dans le texte.** Pensez à tester votre code.

# %%
# Code à compléter
