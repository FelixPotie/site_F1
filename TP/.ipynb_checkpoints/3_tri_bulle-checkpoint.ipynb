# %% [markdown]
# # TP 3 - Tri bulle
#
# Pensez à :
# - tester vos fonctions (pas seulement les tests proposés)
# - vos spécifications et autres commentaires utiles
# - vos compléxité
#
# On a vu les tris par séléction et par insertions. Voici un autre algorithme de tri basique.
#
# Soit `L` une liste de `n` entiers.
#
# ### Premier algorithme
#
# - On parcourt la liste en inversant `L[i]` et `L[i+1]` chaque fois que `L[i] > L[i+1]`.
# - On recommence tant qu'il y a eu des échanges au parcours précédent.
#
# **Question 1 : Créer une fonction `parcours_1(L)` qui parcours une fois `L`, fait les échanges si besoin et renvoie `True` ssi au moins un échange a été réalisé.**

# %%
# Code à compléter

# %% [markdown]
# **Question 2 : Créer la fonction `tri_bulle(L)`.**

# %%
# Code à compléter

# %% [markdown]
# **Question 3 : En faisant afficher la liste après chaque parcours, vérifier la propriété suivante : "À la fin du k-ème parcours, les k plus grands éléments sont à leur place finale". \
# Puis sur papier, essayer de démontrer par récurrence cette proposition.**

# %% [markdown]
# ### Second algorithme
#
# - On parcourt la liste `n-1` fois en inversant `L[i]` et `L[i+1]` chaque fois que `L[i] > L[i+1]`.
# - La k-ème fois, on ne touche pas au k-1 derniers éléments (déjà triés)
#
# **Question 4 : Créer une fonction `parcours_2(L,k)` avec k>0 sur la base de `parcous_1` la liste L sans toucher à ses k-1 derniers éléments en procédant aux inversions vues précédemment.**

# %%
# Code à compléter

# %% [markdown]
# **Question 5 : Créer la fonction `tri_bulle_2(L)` qui réalise ce tri.**

# %%
# Code à compléter

# %% [markdown]
# **Question 6 : Comparer ces 2 fonctions avec n = 1 000, 10 000, 100 000, 1 000 000.**

# %%
import time # Utilisation de la fonction perf_counter()
import random as rd # import du module random qui est renommé rd

n = 1000
L = [rd.randint(0,100*n) for k in range(n)]

t0 = time.perf_counter()
tri_bulle_1(L)
t1 = time.perf_counter()
temps_execution_naturel = t1 - t0

t0 = time.perf_counter()
tri_bulle_2(L)
t1 = time.perf_counter()
temps_execution_memoire = t1 - t0

print("Pour n = " + n)
print("tri_bulle_1 à mis " + temps_execution_memoire)
print("tri_bulle_2 à mis " + temps_execution_memoire)

# %% [markdown]
# **Question 7 : Est-il facile de se retrouver dans le pire des cas de temps d’exécution de ces algorithmes? Donner un exemple de pire cas pour chacune de ces fonctions.**
