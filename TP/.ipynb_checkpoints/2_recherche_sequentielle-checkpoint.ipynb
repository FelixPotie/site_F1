# %% [markdown]
# # TP 2 - Recherche séquentielle
#
# Pensez à tester toutes vos fonctions, si des tests sont déjà présents ne vous privez pas de tester d'autres cas (sur des listes vides par exemple).\
# Pour chaque fonction, mettre ses spécifications et sa compléxité temporelle.

# %% [markdown]
# ## Exercice 1:
# Recherche séquentielle d’un élément dans une liste ou dans une chaîne de caractère
# Pour effectuer une recherche séquentielle d'un élément x dans une liste ou une chaîne de caractère L on procède de la manière suivante :
# - On parcourt les éléments de L un par un
# - Si l'élément en cours correspond à x on renvoie `Vrai`
# - Une fois tous les éléments testés, si aucun ne correspondait à x, on renvoie `Faux`

# %% [markdown]
# **Question 1 : Ecrire une fonction `appartient(x,L)` qui renvoie `True` si x (nombre ou chaine de caractères d’une seule lettre) se trouve dans L (liste ou chaine de caractères) et `False` sinon à l'aide d'une recherche séquentielle**

# %%
# Code à compléter

# %%
appartient(42,[12, 17, 42, 5])
# doit renvoyer True

# %%
appartient(24,[12, 17, 42, 5])
# doit renvoyer True

# %%
appartient('s','testons')
# doit renvoyer True

# %% [markdown]
# **Question 2 : Ecrire une fonction `indice(x,L)` qui renvoie le premier indice où se trouve x s'il est présent dans L et None sinon.** \
# En python `None` permet de dire qu'il n'y a pas de valeur donc ici pas de résultat.\
# Avez-vous besoin de parcourir toute la liste si vous trouvez `x` au début ?

# %%
# Code à compléter

# %%
indice(42,[12, 17, 42, 5])
# doit renvoyer 2

# %%
indice(24,[12, 17, 42, 5])
# doit renvoyer None (dans jupyter rien n'est afficher si None est renvoyé)

# %% [markdown]
# **Question 3 : Ecrire une fonction `liste_positions(x,L)` qui renvoie la liste (éventuellement vide) de toutes les positions de l'élément x dans L**

# %%
# Code à compléter

# %%
liste_positions(42,[12, 17, 42, 5])
# [2]

# %%
liste_positions(24,[12, 17, 42, 5])
# []

# %%
liste_positions('s','testons')
# [2, 6]

# %% [markdown]
# **Question 4: Déterminer le nombre de "a" et de "e" dans l’extrait suivant.**

# %%
extrait = """Anton Voyl n'arrivait pas à dormir. Il alluma. Son Jaz marquait
 minuit vingt. Il poussa un profond soupir, s'assit dans son lit, 
 s'appuyant sur son polochon. Il prit un roman, il l'ouvrit, il lut; 
 mais il n'y saisissait qu'un imbroglio confus, il butait à tout instant 
 sur un mot dont il ignorait la signification.\n Il abandonna son roman 
 sur son lit. Il alla à son lavabo; il mouilla un gant qu'il passa sur 
 son front, sur son cou.\n Son pouls battait trop fort. Il avait chaud. 
 Il ouvrit son vasistas, scruta la nuit. Il faisait doux. Un bruit 
 indistinct montait du faubourg. Un carillon, plus lourd qu'un glas, plus 
 sourd qu'un tocsin, plus profond qu'un bourdon, non loin, sonna trois 
 coups. Du canal Saint-Martin, un clapotis plaintif signalait un chaland 
 qui passait. Sur l'abattant du vasistas, un animal au thorax indigo, à 
 l'aiguillon safran, ni un cafard, ni un charançon, mais plutôt un 
 artison, s'avançait, traînant un brin d'alfa. Il s'approcha, voulant 
 l'aplatir d'un coup vif, mais l'animal prit son vol, disparaissant dans 
 la nuit avant qu'il ait pu l'assaillir."""

# %%
# code à compléter

# %% [markdown]
# ## Exercice 2 : Détermination du maximum d'une liste de nombres
#
# On cherche à déterminer le maximum d’une liste L de nombres. Pour cela on propose deux algorithmes dont nous allons comparer les temps d’exécution.
#
# ### Premier algorithme
# Le principe est le suivant : on compare chaque élément de L avec tous les éléments de L. Si l’élément en cours est plus grand que tous les autres c’est le maximum.
#
# **Question 1 : Corriger l'algorithme `maximum_naturel(L)` suivant.**

# %%
# Code à modifier
def maximum_naturel(L):
    """
    Entrée : L une liste de nombres
    Sortie : maximum de L en utilisant la méthode naturelle : comparaison de chaque élément avec tous les autres
    """
    n = len(L)
    if n = 0:
        print(la liste est vide)
        return None
    for i in range(N):
        v1 = L(i)
        v1_est_plus_grand = True
        for j in range(N+1):
            v2 = L[j]
            if i < j:
                v1_est_plus_grand = False
        if v1_est_plus_grand:
            maximum = i
    return maximum

# %%
maximum_naturel([4, 8, 5])
# 8

# %%
maximum_naturel([])
# None

# %% [markdown]
# ### Deuxième algorithme
#
# Le principe est le suivant: on utilise une variable afin de stocker le maximum provisoire. Voici les étapes:
# - Si la liste est vide, on renvoie `None`
# - On initialise `max_prov` à la valeur du 1er élément de la liste
# - On parcourt les éléments de la liste à l’aide d’une boucle
#     - Si l’élément en cours est plus grand que `max_prov` on met `max_prov` à jour
#     - Sinon, on ne fait rien
# - Une fois arrivé au bout de la liste, on renvoie `max_prov`
#
# **Question 3 : Ecrire une fonction `maximum_memoire(L)` qui renvoie le maximum de L en utilisant ce deuxième algorithme**

# %%
# Code à compléter

# %% [markdown]
# ### Applications
#
# On utilise des modules pour :
# - générer des nombre aléatoire : `randint(a,b)` du module random renvoie un entier choisi aléatoirement entre a et b
# - calculer un delta de temps :  `time.perf_counter()` nous donne le temps à l'instant ou la fonction est appelé

# %% [markdown]
# **Question 4 : Intuitivement, quel est l'algorithme le plus rapide ? Tester vos fonction avec n = 1 000, 10 000, 100 000, 1 000 000. Pouvez-vous confirmer la compléxité de vos fonction ?**

# %%
import time # Utilisation de la fonction perf_counter()
import random as rd # import du module random qui est renommé rd

n = 1000
L = [rd.randint(0,100*n) for k in range(n)]

t0 = time.perf_counter()
maximum_naturel(L)
t1 = time.perf_counter()
temps_execution_naturel = t1 - t0

t0 = time.perf_counter()
maximum_memoire(L)
t1 = time.perf_counter()
temps_execution_memoire = t1 - t0

print("Pour n = " + n)
print("maximum_naturel à mis " + temps_execution_memoire)
print("maximum_memoire à mis " + temps_execution_memoire)

# %% [markdown]
# ## Exercice 3 : Second maximum
#
# On cherche à écrire une fonction qui renvoie le second maximum d’une liste L. On fait l’hypothèse que la liste possède au moins deux éléments différents.
# Attention : aucune des fonctions de cette exercice ne doit modifier la liste L.
#
# **Question 1 : Ecrire une fonction `min_et_max(L)` de complexité linéaire qui renvoie le minimum et le maximum d’une liste de nombres L.**

# %%
# Code à compléter

# %% [markdown]
# **Question 2 : Ecrire une fonction `second_max(L)` qui renvoie le second maximum de L en ne parcourant L qu’une seule fois.**
#
# On suppose que les deux premiers éléments de L sont distincts

# %%
# Code à compléter

# %% [markdown]
# **Question 3 : Ecrire une fonction `indice_second_max(L)` qui renvoie une des positions du second maximum en ne parcourant L qu’une seule fois.**

# %%
# Code à compléter

# %% [markdown]
# ## Exercice 4 : n maximums
#
# Python intègre une fonction `max(L)` qui renvoie le maximum d'une liste. On s'autorise dans cet éxercice à l'utiliser. Cette fonction est de compléxité $O(n)$
#
# **Question 1 : Créer une fonction `n_max(L,n)` renvoyant dans l’ordre, les n premiers maximum de L. Donner sa compléxité temporelle. Que revoie `n_max(L,len(L))` ?**

# %%
# Code à compléter
