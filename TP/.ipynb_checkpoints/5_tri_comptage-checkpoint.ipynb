# %% [markdown]
# # TP 5 - Tri par comptage
#
# On a vu les algorithmes de tris suivant : tri par selection, tri par insertion et tri bulle. Ces tris sont des tris appelés tri par comparaison. Ils utilisent un enchainement de comparaisons (`<` ou`>`), cependant il existe d'autres type de tris qui ne sont pas par comparaison. Nous allons en voir un aujourd'hui.
#
# ## Exercice 1 - Tri d'entiers
#
# Pour commencer, nous allons faire une version où l'on veut trier des entiers compris dans une borne `[0:m]`, où `m` est l'élément maximum de la liste. \
# Pour celà nous allons créer une liste `compteurs` de taille `m` où `compteurs[i]` contiendra le nombre d'occurence de `i` dans la liste. Puis nous n'avons plus qu'à utiliser `compteurs` pour créer une nouvelle liste contenant les éléments initiaux triés.
#
# Par exemple :
# `liste = [1,3,2,2,1]`
# alors :
# `compteurs = [0,2,2,1]`
# et donc :
# `liste_triee = [1,1,2,2,3]`.
#
# **Question 1 : Implémenter une fonction `maximum(liste)` qui prend une liste d'entier et renvoie la valeur de son élément maximum.**

# %%
# code à compléter

# %% [markdown]
# **Question 2 : Implémenter une fonction `tri_comptage_1(liste)` à l'aide d'un tableau et de la fonction `maximum`.**

# %%
# code à compléter

# %% [markdown]
# **Question 3 :**
# 1. Quel est la complexité de cette fonction ?
# 2. Dans quel cas celle-ci est meilleure que les tris que vous connaissez ?
# 3. Dans quel cas cette fonction n'a pas une bonne compléxité ?

# %% [raw]
# Répondez ici

# %% [markdown]
# ## Exercice 2 - Tri de code postaux
#
# Nous voulons maintenant éviter d'avoir une grande compléxité lorsque qu'on a des données avec une borne très grande.\
# Imaginons nous avons une liste de code postaux français (5 chiffres) d'un pannel de personnes et que nous voulions les triées. Nous savons que certains code postaux apparaitront plusieurs fois, et que parmis les code postaux entre `01000` et `99000` il n'y a pas les 98 000 possibilitées possibles.\
# Pour avoir un algorithme plus efficace on peut utiliser un dictionnaire à la place d'une liste pour notre compteur. Les clés représenteront les code postaux et les valeurs le nombre d'occurence présentes.
#
# Malheureusement, on va devoir trier les clés de notre dictionnaire pour que celles-ci soient dans l'ordre croissant.
#
# **Question 1 : Implémenter un tri par sélécction ou par insertion.**

# %%
# Code à compléter

# %% [markdown]
# **Question 2 : Implémenter une fonction `tri_comptage_2(liste)` à l'aide d'un dictionnaire et de votre fonction de tri de la question précédente.**

# %%
# Code à compléter

# %% [markdown]
# Voici une base de donnée de personnes et de leurs code postaux. \
# **Question 3 : Implémenter une fonction `tri_codes_postaux(codes)` qui adapte votre tri par comptage pour trier la liste ci-dessous.**

# %%
dico = {'Jean': 74230, 'Marie': 13008, 'Luc': 31000, 'Sophie': 69003, 'Paul': 74230, 'Claire': 44000, 'Hugo': 13008, 'Emma': 35000, 'Julien': 75015, 'Camille': 59000, 'Nicolas': 75015, 'Laura': 67000, 'Thomas': 33000, 'Julie': 31000, 'Antoine': 35000, 'Alice': 44000, 'Pierre': 67000, 'Sarah': 59000, 'David': 69003, 'Elise': 33000, 'Martin': 31000, 'Chloé': 74230, 'Victor': 75015, 'Manon': 33000, 'Alexandre': 44000, 'Léa': 67000, 'Louis': 13008, 'Zoé': 59000, 'Gabriel': 75015, 'Anaïs': 74230, 'Benjamin': 69003, 'Clément': 33000, 'Mélanie': 31000, 'Adrien': 44000, 'Océane': 35000, 'Florian': 74230, 'Célia': 59000, 'Maxime': 67000, 'Caroline': 13008, 'Samuel': 33000, 'Amandine': 75015, 'Bastien': 31000, 'Inès': 44000, 'Matthieu': 69003, 'Noémie': 35000, 'Guillaume': 13008, 'Aurélie': 59000, 'Quentin': 74230, 'Marion': 67000}

# %%
# Code à compléter
