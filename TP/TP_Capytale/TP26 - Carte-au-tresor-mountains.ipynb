# %% [markdown]
# # Bravo ! Vous avez réussi les énigmes des habitants.
# ## Épreuve 3 : La montagne
# ![image_7911e074](attachment:image_7911e074)
#
# !!! info
# Vous décidez de contourner la montagne jusqu'au trésor mais vous perdez votre chemin. Vous tombez sur une vieille dame qui veut vous aider mais d'abord elle veut s'amuser un peu. Elle vous dit qu'elle à pris cette photo de la montagne et que dedans un secret est caché.
# !!!

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img_pil = Image.open("secret.png")
image = np.array(img_pil)

plt.figure()
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# !!! question
# **La clé est au début et se termine par `###FIN###`. Chaque pixel donne une information via son bit de poids faible. Une fois les bits réuni la clé se révèlera.**
# !!!
