# %% [markdown]
# # TP Bonus : Jeu de la Vie
#
# Dans ce TP, nous allons coder une version basique du **jeu de la Vie**.
#
# Vous pouvez aller voir ce qu'est le jeu de la Vie : https://fr.wikipedia.org/wiki/Jeu_de_la_vie
#
# !!! info Jeu de la vie
# Le jeu de la Vie est un « jeu à zéro joueur », c'est-à-dire qu'il ne nécessite aucune intervention du joueur lors de son déroulement. Il s’agit d’un automate cellulaire, un modèle avec lequel chaque état conduit mécaniquement à l’état suivant à partir de règles préétablies.
#
# Le jeu se déroule sur une grille à deux dimensions, théoriquement infinie, dont les cases — appelées « cellules », par analogie avec les cellules vivantes — peuvent prendre deux états distincts : « vivante » ou « morte ».
# !!!
#
# **Ici, nous allons faire une grille de taille fixe `n*n`, où les cases vivantes seront blanches et les cases mortes noires**

# %% [markdown]
# !!! question Question 1
# Écrire une fonction `afficher_damier(m)` qui prend une matrice `m` de bool et affiche la grille du jeu de la Vie courante. Vous pouvez utiliser "⬛" pour morte et "⬜" pour vivant.
# !!!

# %%
def afficher_damier(m):
    for i in range(len(m)):
        line = ""
        for j in range(len(m[0])):
            if m[i][j]:
                line += "⬛"   # carré noir
            else:
                line += "⬜"   # carré blanc
        print(line)

# %% [markdown]
# !!! info Règle de transition
# Une cellule possède huit voisines, qui sont les cellules adjacentes horizontalement, verticalement et diagonalement.
#
# À chaque itération, l'état d’une cellule est entièrement déterminé par l’état de ses huit cellules voisines, selon les règles suivantes :
# - Une cellule **morte** possédant exactement **trois** cellules voisines vivantes devient **vivante** (elle naît) ;
# - Une cellule **vivante** ne possédant pas exactement **deux ou trois** cellules voisines vivantes **meurt**.
# !!!

# %% [markdown]
# !!! question Question 2
# Écrire une fonction `creer_grille(n, p = 0)` qui initialise une grille de taille `n*n` avec uniquement des cellules mortes si `p == 0`. Sinon `p` est la probabilité (0 < p < 1) que la cellule soit vivante, on tire donc, pour chaque cellule, aléatoirement un nombre entre 0 et 1 pour savoir si elle est vivante ou non.
#
# Vous utiliserez la fonction `random()` de la bibliothèque random qui renvoie un float entre 0 et 1.
# !!!

# %%
import random

print(random.random())
# Out:
# 0.5498703898423116

# %%
def creer_grille(n, p = 0):
    return [[True if random.random() < p else False for _ in range(n)] for _ in range(n)]

# %% [markdown]
# !!! question Question 3
# Écrire une fonction `nb_voisins_vivants(m, i, j)` qui en fonction d'une grille `m` et d'une position de cellule `i`,`j` renvoie le nombre de voisins vivants de cette cellule.\
# On compte les lignes et colonnes hors de la grille comme des cellules mortes.
# !!!

# %%
def incr_compteur(m, i, j, cpt):
    n = len(m)
    if i >= 0 and i<n and j >= 0 and j < n and m[i][j] : # on est dans la grille et c'est en vie
        return cpt + 1
    return cpt

def nb_voisins_vivants(m, i, j):
    cpt = 0 
    n = len(m)
    for x in range(-1,2):
        for y in range(-1,2):
            if x != 0 or y != 0 : # on ne compte pas m[i][j]
                cpt = incr_compteur(m, i+x, j+y, cpt)
    return cpt

# %% [markdown]
# !!! question Question 4
# Écrire une fonction `etape_jeu_de_la_vie(m)` qui en fonction d'une grille `m` renvoie la grille suivante du jeu de la vie.
# !!!

# %%
def etape_jeu_de_la_vie(m):
    n = len(m)
    nouvelle_grille = creer_grille(n)
    for i in range(n):
        for j in range(n):
            nb_voisins = nb_voisins_vivants(m,i,j)
            if m[i][j] and (nb_voisins == 3 or nb_voisins == 2):
                nouvelle_grille[i][j] = True
            if not m[i][j] and nb_voisins == 3 :
                nouvelle_grille[i][j] = True
    return nouvelle_grille

# %%
g = creer_grille(10, 0)
g[3][1] = True
g[3][2] = True
g[3][3] = True


for i in range(10):
    print(f"Generation {i}")
    afficher_damier(g)
    g = etape_jeu_de_la_vie(g)
# Out:
# Generation 0
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬛⬛⬛⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# Generation 1
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# Generation 2
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬛⬛⬛⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# Generation 3
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# Generation 4
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬛⬛⬛⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# Generation 5
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# Generation 6
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬛⬛⬛⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ...

# %% [markdown]
# !!! question Question 5
# Créez un GIF d'une exécution du jeu de la Vie en exécutant le code suivant. Vous pouvez modifier les paramètres pour voir plusieurs exécutions.
# !!!

# %%
import matplotlib.pyplot as plt
import random
import imageio
from io import BytesIO
from IPython.display import Image, display


# paramètres (adaptables)
n = 60
nombre_de_simulation = 100
g = creer_grille(n, 0.25)


# préparer la figure 
fig, ax = plt.subplots(figsize=(6,4))
ax.axis('off')

# on collecte les images en mémoire pour écrire un gif
frames = []
for i in range(taille_grille):
    ax.clear()
    ax.axis('off')
    ax.imshow(g, interpolation='nearest', cmap='gray_r', vmin=0, vmax=1)
    ax.set_title(f"Génération {i+1}", fontsize=10)
    # sauvegarde la figure dans un buffer png
    buf = BytesIO()
    fig.savefig(buf, format='png', bbox_inches='tight', pad_inches=0)
    buf.seek(0)
    # lire l'image depuis le buffer avec imageio 
    frames.append(imageio.v2.imread(buf))
    buf.close()
    g = etape_jeu_de_la_vie(g) # appelle de la fonction de l'étape suivante

# créer le GIF en mémoire
gif_buf = BytesIO()
imageio.mimsave(gif_buf, frames, format='GIF', fps=6)
gif_buf.seek(0)

# afficher dans Basthon via data
display(Image(data=gif_buf.read()))

# %% [markdown]
# **Bravo !**
