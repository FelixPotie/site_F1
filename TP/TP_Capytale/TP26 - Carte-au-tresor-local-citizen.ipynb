# %% [markdown]
# # Bravo ! Vous êtes sortie du temple.
# ## Épreuve 2 : Les habitants de l'île
#
# ![image_613862ce](attachment:image_613862ce)
# !!! info
# Vous continuez votre chemin et tombez sur un groupe de personnes, ce sont les personnes vivant ici. Ils sont joueurs et veulent vous poser une énigme. Avant celà ils vous apprennent 2 choses qui vous seront utile :
# + Pour traduire un nombre binaire utiliser `int(bin_str, 2)` par exemple `int("00101010", 2) = 42`
# + Pour faire un XOR (ou exclusif) entre 2 int faites `x ^ y`
# !!!

# %% [markdown]
# !!! question Énigme 1
# Ils vous donnent ensuite cette énigme : \
# **En me regroupant par octet je me dévoile.**
# !!!

# %%
message_a_decoder = '...'

# %% [markdown]
# !!! question Énigme 2
# **La clé sera répété autant que nécessaire, chaque caractère se verra être un ou exclusif avec un caractère de la clé**
# !!!

# %%
message_a_decoder = "00100010010100100010010101010101011010110000000001110111000000110111000000000010011100100000001001110100"
