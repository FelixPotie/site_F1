# %% [markdown]
# # TP 2 - Boucles et listes : des bases solides
#
# !!! tip Rappels
# Pensez à tester toutes vos fonctions, si des tests sont déjà présents ne vous privez pas de tester d'autres cas.\
# Commenter votre code pour les parties complexes.
# !!!

# %% [markdown]
# ## Exercice 1 : Nombres parfaits
#
# L'objectif de cet exercice est de trouver les nombres parfaits.
# !!! info Nombre parfait
# En arithmétique, un nombre parfait est un entier naturel égal à la somme de ses diviseurs positifs sauf lui-même (diviseurs stricts). \
# Ainsi 6 est un nombre parfait, car ses diviseurs positifs sont 1, 2, 3 et 6, et il vérifie bien 6 = 1 + 2 + 3.\
# Mais 12 n'est pas un nombre parfait, car ses diviseurs positifs sont 1, 2, 3, 4, 6 et 12, mais 1 + 2 + 3 + 4 + 6 = 16.
# !!!
# Pour arriver à ce résultat, on va effectuer des fonctions intermédiaires.
#
# !!! question Question 1
# Écrivez une fonction `liste_diviseurs(n)` qui, étant donné un entier naturel `n`, renvoie la liste des diviseurs positifs de `n` qui sont strictement inférieurs à `n`.
#
# Vous pourrez vous aider des instructions :
# - `a // b` : qui renvoie le quotien de la division de a par b
# - `a % b` : qui renvoie le reste de la division de a par b
# !!!

# %%
# code à compléter

# %%
print(liste_diviseurs(50)) 
# doit renvoyer [1,2,5,10,25]

# %% [markdown]
# !!! question Question 2
# Écrivez une fonction `somme_1(t)` qui, étant donné une liste de nombres `t`, renvoie la somme de ses éléments en itérant sur les **indices** de `t`.
# !!!

# %%
# code à compléter

# %%
# Test à compléter (testez par exemple sur une valeur et sur la liste vide)

# %% [markdown]
# !!! question Question 3
# Écrivez une fonction `somme_2(t)` équivalente, mais en itérant sur les **éléments** de `t`.
# !!!

# %%
# code à compléter

# %%
# Test à compléter

# %% [markdown]
# !!! question Question 4
# **En utilisant les fonctions précédentes**, écrivez une fonction `est_parfait(n)` qui renvoie `True` si l’entier `n` est parfait et `False` sinon.
# !!!

# %%
# code à compléter

# %%
print(est_parfait(6)) # True

# %%
print(est_parfait(8)) # False

# %% [markdown]
# !!! question Question 5
# Écrivez une fonction `liste_parfait_1(n)` qui renvoie la liste des premiers nombres parfaits inférieurs ou égaux à `n`
# !!!

# %%
# code à compléter

# %%
print(liste_parfait_1(1000))
# doit renvoyer [6,28,496]

# %% [markdown]
# !!! question Question 6
# Trouvez le 4<sup>ème</sup> nombre parfait à l'aide d'un programme
# !!!

# %%
# code à compléter

# %% [markdown]
# ## Exercice 2 : Recherche séquentielle
# Recherche séquentielle d’un élément dans une liste ou dans une chaîne de caractère.\
# Pour effectuer une recherche séquentielle d'un élément x dans une liste ou une chaîne de caractère t on procède de la manière suivante :
# - On parcourt les éléments de t un par un
# - Si l'élément en cours correspond à x on renvoie `Vrai`
# - Une fois tous les éléments testés, si aucun ne correspondait à x, on renvoie `Faux`

# %% [markdown]
# !!! question Question 1
# Écrire une fonction `appartient(x,t)` qui renvoie `True` si x (nombre ou chaine de caractères d’une seule lettre) se trouve dans t (liste ou chaine de caractères) et `False` sinon à l'aide d'une recherche séquentielle
# !!!

# %%
# Code à compléter

# %%
print(appartient(42,[12, 17, 42, 5]))
# doit renvoyer True

# %%
print(appartient(24,[12, 17, 42, 5]))
# doit renvoyer False

# %%
print(appartient('s','testons'))
# doit renvoyer True

# %% [markdown]
# !!! abstract `in`
# Vous venez de coder une fonctionnalité qui existe déjà en Python. On peut connaitre la présence d'un élément dans une liste en utilisant le mot clé `in` de cette façon : \
# `x in t`\
# À l'inverse si on cherche la non-présence, on peut utiliser les mots clés `not in`.
# !!!

# %%
print(42 in [12, 17, 42, 5])

# %%
print(9 not in [12, 17, 42, 5])

# %% [markdown]
# !!! abstract `None`
# En python `None` permet de dire qu'il n'y a pas de valeur donc ici pas de résultat. Une fonction sans return retourne `None` par défaut, on peut aussi écrire `return None` si besoin.
# !!!
#
# !!! question Question 2
# Écrire une fonction `indice(x,t)` qui renvoie le premier indice où se trouve `x` s'il est présent dans `t` et `None` sinon.\
# Avez-vous besoin de parcourir toute la liste si vous trouvez `x` au début ?
# !!!

# %%
# Code à compléter

# %%
print(indice(42,[12, 17, 42, 5]))
# doit renvoyer 2

# %%
print(indice(24,[12, 17, 42, 5]))
# doit renvoyer None

# %% [markdown]
# !!! question Question 3
# Écrire une fonction `liste_positions(x,t)` qui renvoie la liste (éventuellement vide) de toutes les positions de l'élément `x` dans `t`.
# !!!

# %%
# Code à compléter

# %%
print(liste_positions(42,[12, 17, 42, 5]))
# [2]

# %%
print(liste_positions(24,[12, 17, 42, 5]))
# []

# %%
print(liste_positions('s','testons'))
# [2, 6]

# %% [markdown]
# !!! question Question 4
# Déterminer le nombre de "a" et de "e" dans l’extrait suivant.
# !!!

# %%
extrait = """Anton Voyl n'arrivait pas à dormir. Il alluma. Son Jaz marquait
 minuit vingt. Il poussa un profond soupir, s'assit dans son lit, 
 s'appuyant sur son polochon. Il prit un roman, il l'ouvrit, il lut; 
 mais il n'y saisissait qu'un imbroglio confus, il butait à tout instant 
 sur un mot dont il ignorait la signification.\n Il abandonna son roman 
 sur son lit. Il alla à son lavabo; il mouilla un gant qu'il passa sur 
 son front, sur son cou.\n Son pouls battait trop fort. Il avait chaud. 
 Il ouvrit son vasistas, scruta la nuit. Il faisait doux. Un bruit 
 indistinct montait du faubourg. Un carillon, plus lourd qu'un glas, plus 
 sourd qu'un tocsin, plus profond qu'un bourdon, non loin, sonna trois 
 coups. Du canal Saint-Martin, un clapotis plaintif signalait un chaland 
 qui passait. Sur l'abattant du vasistas, un animal au thorax indigo, à 
 l'aiguillon safran, ni un cafard, ni un charançon, mais plutôt un 
 artison, s'avançait, traînant un brin d'alfa. Il s'approcha, voulant 
 l'aplatir d'un coup vif, mais l'animal prit son vol, disparaissant dans 
 la nuit avant qu'il ait pu l'assaillir."""

# %%
# code à compléter

# %% [markdown]
# ## Exercice 3 : Détermination des maximums d'une liste de nombres
#
# On cherche dans un premier temps à déterminer le minimum d'une liste.
#
# Le principe est le suivant: on utilise une variable afin de stocker le maximum provisoire. Voici les étapes:
# - Si la liste est vide, on renvoie `None`
# - On initialise une variable `max` à la valeur du 1er élément de la liste
# - On parcourt les éléments de la liste à l’aide d’une boucle
#     - Si l’élément en cours est plus grand que `max` on met `max` à jour
#     - Sinon, on ne fait rien
# - Une fois arrivé au bout de la liste, on renvoie `max`

# %% [markdown]
# !!! question Question 1
# Écrire la fonction `maximum(liste)`
# !!!

# %%
# Code à compléter

# %%
print(maximum([])) # None

# %%
print(maximum([3,4,2,8])) # 8

# %% [markdown]
# On cherche à écrire une fonction qui renvoie le second maximum d’une liste `liste`. On fait l’hypothèse que la liste possède au moins deux éléments différents.
#
# !!! abstract `assert`
# On veut s'assurer qu'une **pré-condition** est vérifiée sur les entrées c'est-à-dire que faire en sorte que notre fonction ne puisse être appelée que si certains paramètres vérifient certaines conditions. \
# Par exemple, ici, on veut une liste d'au moins 2 éléments. On peut utiliser la programmation **défensive** en vérifiant les pré-conditions au début de notre fonction grâce aux `assert`.
#
# `assert condition` : ne fait rien si `condition` est `True` et renvoie une erreur si `condition` est `False`
# !!!

# %%
assert True

# %%
assert x == 4

# %% [markdown]
# !!! question Question 2
# Écrire une fonction `min_et_max(liste)` qui **affiche** le minimum et le maximum d’une liste de nombres. Vous ne ferez qu'un seul parcours de cette liste. Pensez à utiliser un `assert` pour vérifier que la liste contient au moins 2 éléments.
# !!!

# %%
# Code à compléter

# %%
min_et_max([1]) # doit renvoyer une AssertionError

# %%
min_et_max([3,2,7,1,5]) # doit afficher "1 est le minimum et 7 est le maximum"

# %% [markdown]
# !!! abstract tuple
# En Python, on peut avoir des couples. Ceux-ci sont appelés des tuples. On les note comme ceci : \
# `(a, b)` : a est le premier élément et b le second (ce sont ici des variables).
# !!!
# !!! question Question 3
# Réécrire la fonction `min_et_max(liste)` pour qu'elle retourne un tuple `(min, max)`.
# !!!

# %%
# Code à compléter

# %%
print(min_et_max([1])) # doit renvoyer une AssertionError

# %%
print(min_et_max([3,2,7,1,5])) # (1,7)

# %% [markdown]
# !!! question Question 4
# Écrire une fonction `second_max(liste)` qui renvoie le second maximum de `liste` en ne parcourant `liste` qu’une seule fois.
# !!!

# %%
# Code à compléter

# %%
# Test à compléter ici

# %% [markdown]
# !!! question Question 5
# Écrire une fonction `indice_second_max(liste)` qui renvoie une des positions du second maximum en ne parcourant `liste` qu’une seule fois.
# !!!

# %%
# Code à compléter

# %%
# Test à compléter ici

# %% [markdown]
# !!! abstract max(liste)
# Python intègre une fonction `max(liste)` qui renvoie le maximum d'une liste. On s'autorise, dans les questions qui suivent, à l'utiliser.
# !!!
#
# !!! question Question 6
# Créer une fonction `n_max(liste,n)` renvoyant dans l’ordre, les `n` premiers maximum de `liste`.
# !!!

# %%
# Code à compléter

# %%
n_max([3,5,8,6,5,3,5,9,10,3,12],4) # [12,10,9,8]

# %% [markdown]
# !!! question Question 7
# Que renvoie `n_max(liste,len(liste))` ?
# !!!

# %% [raw]
# Répondre ici
